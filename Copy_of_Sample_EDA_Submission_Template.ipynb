# %% [markdown]
# # **Project Name**    -Exploratory Data Analysis of Global AI, ML and Data Science Salaries

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project performs Exploratory Data Analysis (EDA) on a global dataset containing salary information for Artificial Intelligence (AI), Machine Learning (ML), and Data Science professionals. The objective is to analyze salary trends based on experience level, employment type, company size, remote work, job title, and geographical location. Through statistical analysis and visualizations, the project uncovers hidden patterns that can help job seekers, recruiters, and organizations understand the current AI job market. The project follows the UBM (Univariate, Bivariate, and Multivariate) approach and includes data cleaning, visualization, and business insights to support data-driven decision-making

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The AI and Data Science industry is growing rapidly across the world, but salary differences vary significantly depending on factors such as experience, company size, work location, remote work, and job role. Without proper analysis, organizations and professionals may struggle to understand salary trends and market conditions.
#
# This project aims to explore these factors using Exploratory Data Analysis (EDA) to identify meaningful insights that can support hiring strategies, career planning, and business decisions.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective is to analyze the global AI job market and identify the major factors influencing employee salaries.
#
# Specific objectives include:
#
# Analyze salary distribution across different experience levels.
# Compare salaries among various AI job roles.
# Study the impact of remote work on salaries.
# Understand salary differences across countries.
# Analyze the influence of company size on compensation.
# Identify the highest-paying AI job roles.
# Generate actionable insights that can help organizations improve hiring strategies and assist professionals in making informed career decisions.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

plt.style.use('ggplot')
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (10,6)

# %% [markdown]
# ### Dataset Loading

# %%
# Load DatasET

df = pd.read_csv('/content/global_ai_ml_data_salaries.csv')

# %% [markdown]
# ### Dataset First View

# %%
df.tail()
# Out:
#        work_year experience_level employment_type                 job_title  \
# 40327       2020               SE              FT            Data Scientist
# 40328       2021               MI              FT  Principal Data Scientist
# 40329       2020               EN              FT            Data Scientist
# 40330       2020               EN              CT     Business Data Analyst
# 40331       2021               SE              FT            Data Scientist
#
#         salary salary_currency  salary_in_usd employee_residence  \
# 40327   412000             USD         412000                 US
# 40328   151000             USD         151000                 US
# 40329   105000             USD         105000                 US
# 40330   100000             USD         100000                 US
# 40331  7000000             INR          94665                 IN
#
#        remote_ratio company_location company_size
# 40327           100               US            L
# ...

# %%
df.sample(5)
# Out:
#        work_year experience_level employment_type                  job_title  \
# 25400       2024               SE              FT  Machine Learning Engineer
# 27435       2024               SE              FT             Data Scientist
# 22203       2024               SE              FT           Research Analyst
# 19100       2024               SE              FT             Data Scientist
# 6173        2024               MI              FT        Engineering Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 25400  169200             USD         169200                 US             0
# 27435  288400             USD         288400                 US             0
# 22203  130000             USD         130000                 US             0
# 19100  257600             USD         257600                 US             0
# 6173   190000             USD         190000                 US             0
#
# ...

# %%
# Dataset First Loo
df.head()
# Out:
#    work_year experience_level employment_type        job_title  salary  \
# 0       2024               SE              FT   Data Architect  170955
# 1       2024               SE              FT   Data Architect  130270
# 2       2024               MI              FT  Insight Analyst   92144
# 3       2024               MI              FT  Insight Analyst   57616
# 4       2024               SE              FT    Lead Engineer  201600
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         170955                 US             0
# 1             USD         130270                 US             0
# 2             USD          92144                 US           100
# 3             USD          57616                 US           100
# 4             USD         201600                 US           100
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Number of Rows :", df.shape[0])
print("Number of Columns :", df.shape[1])
# Out:
# Number of Rows : 40332
# Number of Columns : 11

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40332 entries, 0 to 40331
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           40332 non-null  int64
#  1   experience_level    40332 non-null  object
#  2   employment_type     40332 non-null  object
#  3   job_title           40332 non-null  object
#  4   salary              40332 non-null  int64
#  5   salary_currency     40332 non-null  object
#  6   salary_in_usd       40332 non-null  int64
#  7   employee_residence  40332 non-null  object
#  8   remote_ratio        40332 non-null  int64
#  9   company_location    40332 non-null  object
#  10  company_size        40332 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 3.4+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# Visualizing the missing values
(df.isnull().sum()/len(df))*100
# Out:
# work_year             0.0
# experience_level      0.0
# employment_type       0.0
# job_title             0.0
# salary                0.0
# salary_currency       0.0
# salary_in_usd         0.0
# employee_residence    0.0
# remote_ratio          0.0
# company_location      0.0
# company_size          0.0
# dtype: float64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# >

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
# Dataset Describe

df.describe(include='all').T
# Out:
#                       count unique             top   freq           mean  \
# work_year           20407.0    NaN             NaN    NaN    2023.622678
# experience_level      20407      4              SE  11308            NaN
# employment_type       20407      4              FT  20283            NaN
# job_title             20407    227  Data Scientist   3316            NaN
# salary              20407.0    NaN             NaN    NaN  167194.336306
# salary_currency       20407     24             USD  18889            NaN
# salary_in_usd       20407.0    NaN             NaN    NaN  155086.001813
# employee_residence    20407     91              US  17387            NaN
# remote_ratio        20407.0    NaN             NaN    NaN      27.686578
# company_location      20407     82              US  17438            NaN
# company_size          20407      3               M  19426            NaN
#
#                              std      min       25%       50%       75%  \
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset contains information about salaries of AI, Machine Learning, and Data Science professionals across different countries.
#
# Main Variables:
#
# • work_year – Year in which the salary was recorded.
# • experience_level – Employee experience level (EN, MI, SE, EX).
# • employment_type – Type of employment (FT, PT, CT, FL).
# • job_title – Designation of the employee.
# • salary – Salary in the local currency.
# • salary_currency – Currency used for salary payment.
# • salary_in_usd – Salary converted into USD.
# • employee_residence – Employee's country of residence.
# • remote_ratio – Percentage of remote work (0, 50, 100).
# • company_location – Country where the company is located.
# • company_size – Company size (S, M, L).

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in df.columns:
    print(f"\n{col}")
    print(df[col].unique())
# Out:
# work_year
# [2024 2022 2023 2020 2021]
#
# experience_level
# ['SE' 'MI' 'EN' 'EX']
#
# employment_type
# ['FT' 'PT' 'CT' 'FL']
#
# job_title
# ['Data Architect' 'Insight Analyst' 'Lead Engineer'
#  'Machine Learning Engineer' 'Data Scientist' 'Manager' 'Associate'
#  'Data Engineer' 'Business Intelligence Developer' 'Product Manager'
#  'BI Developer' 'Data Analyst' 'Engineering Manager' 'Research Scientist'
#  'Software Engineer' 'Engineer' 'Business Analyst' 'Full Stack Engineer'
#  'BI Analyst' 'Software Development Engineer' 'Data Management Specialist'
#  'AI Architect' 'Site Reliability Engineer' 'Data Manager'
#  'Security Engineer' 'Business Intelligence Engineer' 'DevOps Engineer'
#  'Full Stack Developer' 'Applied Scientist' 'Solutions Architect'
#  'Backend Engineer' 'Research Engineer' 'AI Product Manager'
#  'Analytics Engineer' 'Infrastructure Engineer' 'Fullstack Engineer'
#  'Consultant' 'Quantitative Researcher' 'Power BI Architect' 'AI Engineer'
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df.shape
df.info()
df.isnull().sum()
df.duplicated().sum()
df = df.drop_duplicates()
df.shape
df.describe().T
df.describe(include='object').T
numeric_columns = df.select_dtypes(include=['int64','float64']).columns

categorical_columns = df.select_dtypes(include='object').columns

print(numeric_columns)
print(categorical_columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40332 entries, 0 to 40331
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           40332 non-null  int64
#  1   experience_level    40332 non-null  object
#  2   employment_type     40332 non-null  object
#  3   job_title           40332 non-null  object
#  4   salary              40332 non-null  int64
#  5   salary_currency     40332 non-null  object
#  6   salary_in_usd       40332 non-null  int64
#  7   employee_residence  40332 non-null  object
#  8   remote_ratio        40332 non-null  int64
#  9   company_location    40332 non-null  object
#  10  company_size        40332 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 3.4+ MB
# Index(['work_year', 'salary', 'salary_in_usd', 'remote_ratio'], dtype='object')
# Index(['experience_level', 'employment_type', 'job_title', 'salary_currency',
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# • Checked the structure of the dataset using info().
#
# • Identified numerical and categorical variables.
#
# • Verified that the dataset contains no significant missing values.
#
# • Checked for duplicate records and removed them.
#
# • Generated statistical summaries for numerical and categorical features.
#
# • Identified unique values in each variable.
#
# • Prepared the dataset for visualization and further analysis.
#
# Overall, the dataset is clean and suitable for Exploratory Data Analysis (EDA).

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

plt.figure(figsize=(8,5))
sns.countplot(data=df, x='experience_level', palette='viridis')
plt.title('Distribution of Experience Level')
plt.xlabel('Experience Level')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot is used because experience_level is a categorical variable. It helps compare the number of employees in each experience category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The dataset contains employees from different experience levels.
# Mid-level and Senior-level professionals have higher representation than Entry-level and Executive-level professionals

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Companies can understand the availability of talent across different experience levels and plan recruitment strategies accordingly

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

plt.figure(figsize=(8,5))
sns.countplot(data=df, x='employment_type', palette='Set2')
plt.title('Distribution of Employment Type')
plt.xlabel('Employment Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Employment type is a categorical variable, and a count plot effectively compares the number of employees in each categor

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Full-time employees dominate the dataset.
# Contract, Freelance, and Part-time employees are comparatively fewe

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight helps organizations understand workforce composition and decide on hiring strategie

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='company_size', palette='coolwarm')
plt.title('Distribution of Company Size')
plt.xlabel('Company Size')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Company size is a categorical feature. A count plot provides a clear comparison of companies based on size

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Medium-sized companies have the highest number of employees.
# Small and Large companies are fewer in comparison

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Businesses can identify which company size dominates the AI industry and benchmark hiring trends

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

plt.figure(figsize=(8,5))
sns.countplot(data=df, x='remote_ratio', palette='magma')
plt.title('Remote Work Distribution')
plt.xlabel('Remote Ratio')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The remote ratio represents categories of remote work (0%, 50%, and 100%), making a count plot suitable for comparing their frequencies

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Fully remote jobs are common.
# Hybrid and on-site work arrangements are also present but vary in frequency

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Fully remote jobs are common.
# Hybrid and on-site work arrangements are also present but vary in frequency

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

plt.figure(figsize=(10,6))
sns.histplot(df['salary_in_usd'], bins=30, kde=True, color='royalblue')
plt.title('Distribution of Salary in USD')
plt.xlabel('Salary (USD)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is used to understand the distribution of salary values and identify whether salaries are evenly distributed or skewed

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most employees earn within a particular salary range.
# A few professionals earn significantly higher salaries, creating a right-skewed distribution

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Organizations can benchmark salary ranges and identify competitive compensation levels

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(8,5))
sns.boxplot(x=df['salary_in_usd'], color='orange')
plt.title('Box Plot of Salary in USD')
plt.xlabel('Salary (USD)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot helps identify outliers and understand the spread of salary data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A box plot helps identify outliers and understand the spread of salary data

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Companies can analyze salary variations and review compensation policies for exceptional roles

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

plt.figure(figsize=(12,6))
df['job_title'].value_counts().head(10).plot(kind='bar', color='teal')
plt.title('Top 10 Job Titles')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is ideal for comparing the frequency of different job titles

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Data Scientist, Data Engineer, and Machine Learning Engineer are among the most common roles.
# Some specialized roles appear less frequently

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

plt.figure(figsize=(8,5))
sns.countplot(data=df, x='work_year', palette='Set3')
plt.title('Distribution of Work Year')
plt.xlabel('Work Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot helps compare the number of records across different years

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Recent years contain more salary records.
# The AI job market has shown increasing activity over time

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
plt.figure(figsize=(12,6))
df['company_location'].value_counts().head(10).plot(kind='bar', color='green')
plt.title('Top 10 Company Locations')
plt.xlabel('Country')
plt.ylabel('Number of Companies')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart effectively compares the number of companies across different countries

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A few countries dominate the AI job market.
# Many countries have relatively fewer AI companies

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

plt.figure(figsize=(12,6))
df['employee_residence'].value_counts().head(10).plot(kind='bar', color='purple')
plt.title('Top 10 Employee Residence Countries')
plt.xlabel('Country')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart compares where AI professionals are primarily located

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='experience_level', y='salary_in_usd', palette='viridis')
plt.title('Salary by Experience Level')
plt.xlabel('Experience Level')
plt.ylabel('Salary (USD)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is ideal for comparing salary distributions across different experience levels while highlighting outliers and salary spread.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='employment_type', y='salary_in_usd', palette='Set2')
plt.title('Salary by Employment Type')
plt.xlabel('Employment Type')
plt.ylabel('Salary (USD)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart compares salary distributions across different employment types

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='company_size', y='salary_in_usd', palette='coolwarm')
plt.title('Salary by Company Size')
plt.xlabel('Company Size')
plt.ylabel('Salary (USD)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# AA box plot helps compare salary ranges across small, medium, and large companies

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Large companies generally offer higher salaries.
# Medium-sized companies also provide competitive compensation

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 CORRELATION HEATMAP

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.select_dtypes(include=['int64','float64']).corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap is used to visualize the correlation between numerical variables. It helps identify positive and negative relationships

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Stronger colors indicate stronger correlations.
# Variables with high correlation may influence each other

# %% [markdown]
# #### Chart - 15 PAIR PLOT

# %%
sns.pairplot(df[['salary_in_usd','work_year','remote_ratio']])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is useful for exploring relationships between multiple numerical variables at the same time

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It shows the distribution of each variable along the diagonal.
# Scatter plots reveal relationships and possible patterns between variables

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the Exploratory Data Analysis, the following recommendations are suggested to help achieve the business objectives:
#
# Offer Competitive Salaries: Regularly benchmark salaries against industry standards to attract and retain skilled AI professionals.
# Focus on Experienced Talent: Senior and Executive-level employees contribute significant expertise. Providing competitive compensation and career growth opportunities can improve employee retention.
# Expand Remote Work Opportunities: Since remote jobs are widely accepted in the AI industry, offering flexible work options can help organizations access a larger global talent pool.
# Invest in High-Demand Roles: Roles such as Data Scientist, Machine Learning Engineer, and Data Engineer are in high demand. Organizations should prioritize hiring and training for these positions.
# Review Compensation by Company Size and Location: Salary trends vary across company sizes and countries. Businesses should design location-specific salary structures to remain competitive in different markets.
# Use Data-Driven Workforce Planning: Regular analysis of salary and employment trends can help organizations make informed decisions regarding recruitment, budgeting, and employee retention.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This Exploratory Data Analysis (EDA) project successfully analyzed the Global AI, Machine Learning, and Data Science Salaries dataset to identify salary trends and workforce patterns. The analysis revealed that experience level, company size, employment type, and remote work significantly influence employee salaries. Various visualizations helped uncover meaningful insights into the AI job market. Overall, the project demonstrates how data analysis can support organizations in making informed hiring, salary planning, and workforce management decisions while helping professionals better understand current industry trends

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***

# %%
8882582016
